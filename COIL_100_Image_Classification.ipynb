# %% [markdown]
# <a href="https://colab.research.google.com/github/Jarmos-san/COIL-100/blob/master/COIL_100_Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

import tensorflow_datasets as tfds

# %%
# different settings
tfds.disable_progress_bar()

# %%
print(f'TensorFlow v{tf.__version__}')
print(f'TensorFlow Datasets v{tfds.__version__}')
# Out:
# TensorFlow v2.2.0-rc3
# TensorFlow Datasets v2.1.0

# %%
# Load the Coil100 v1.0.0 dataset
data, info = tfds.load('coil100:1.0.0', split='train', with_info=True)
print(info)
# Out:
# tfds.core.DatasetInfo(
#     name='coil100',
#     version=1.0.0,
#     description='The dataset contains 7200 color images of 100 objects
# (72 images per object). The objects have a wide variety of complex geometric and reflectance characteristics.
# The objects were placed on a motorized turntable against a black background.
# The turntable was rotated through 360 degrees to vary object pose with respect to a fxed color camera.
# Images of the objects were taken at pose intervals of	5 degrees.This corresponds to
# 72 poses per object',
#     homepage='http://www.cs.columbia.edu/CAVE/software/softlib/coil-100.php',
#     features=FeaturesDict({
#         'image': Image(shape=(128, 128, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=72),
#         'object_id': Text(shape=(), dtype=tf.string),
#     }),
#     total_num_examples=7200,
#     splits={
#         'train': 7200,
#     },
#     supervised_keys=('image', 'label'),
# ...

# %%
fig = tfds.show_examples(info, data)
